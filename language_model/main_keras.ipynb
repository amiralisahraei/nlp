# %%
import numpy as np
import re
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense, Dropout, BatchNormalization
from keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %% [markdown]
# ### Reead data and split it per line

# %%
def read_prepare_data(file_path):
    with open(file_path, 'r') as f:
        data = f.read().strip()
        data = re.sub("[^a-zA-Z0-9 ,.:? \n]", "", data)
        data = data.lower().split('\n')
        data = [line for line in data if line]
    return data

file_path = "/kaggle/input/shekspier/Shekspier.txt"
data = read_prepare_data(file_path)
print(data[0:4])
# Out:
# ['first citizen:', 'before we proceed any further, hear me speak.', 'all:', 'speak, speak.']

# %% [markdown]
# ### Tokenizer and Padding

# %%
def init_tokenizer():
    # initialize the tokenizer
    tkn = Tokenizer()
    tkn.fit_on_texts(data)
    # +1 to handle the words the tokenizer has not seen before
    nmu_unique_words = len(tkn.word_index) + 1
    return (tkn, nmu_unique_words)
tokenizer, nmu_unique_words = init_tokenizer()

def tokenize_data_padding(raw_data):
    seq = tkn.texts_to_sequences(raw_data)
    seq = [sample for sample in seq if len(sample) >= 2]
    max_length = max([len(sample) for sample in seq])
    data = pad_sequences(seq, padding = 'pre', maxlen= max_length)
    return data
data = tokenize_data_padding(data)

# %% [markdown]
# ### Separate X and y and one-hot encoding

# %%
X = data[:,:-1]
y = data[:,-1]

input_size = X.shape[1]
y = to_categorical(y, nmu_unique_words)

# %% [markdown]
# ### Creat model and train it

# %%
def lstm_model(input_dim, input_size, output_dim=100):
    model = Sequential()
    model.add(Embedding(input_dim, output_dim))
    model.add(BatchNormalization())
    model.add(LSTM(128))
    model.add(Dropout(0.1))
    model.add(Dense(input_dim, activation="softmax"))
    model.build(input_shape=(1, input_size))
    model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=["accuracy"])
    return model

model = lstm_model(nmu_unique_words, input_size)
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding_7 (Embedding)         │ (1, 15, 100)           │     1,275,100 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (1, 15, 100)           │           400 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_7 (LSTM)                   │ (1, 128)               │       117,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (1, 128)               │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (1, 12751)             │     1,644,879 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 3,037,627 (11.59 MB)
#  Trainable params: 3,037,427 (11.59 MB)
#  Non-trainable params: 200 (800.00 B)

# %%
history=model2.fit(X, y, epochs=70, batch_size=128)
# Out:
# Epoch 1/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8721 - loss: 0.4753
# Epoch 2/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8662 - loss: 0.4811
# Epoch 3/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8680 - loss: 0.4839
# Epoch 4/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8712 - loss: 0.4664
# Epoch 5/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8666 - loss: 0.4837
# Epoch 6/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8635 - loss: 0.4874
# Epoch 7/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8722 - loss: 0.4614
# Epoch 8/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8722 - loss: 0.4710
# Epoch 9/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8761 - loss: 0.4558
# Epoch 10/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8726 - loss: 0.4630
# Epoch 11/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8740 - loss: 0.4542
# Epoch 12/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8727 - loss: 0.4610
# Epoch 13/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8716 - loss: 0.4632
# Epoch 14/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8732 - loss: 0.4660
# Epoch 15/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8686 - loss: 0.4774
# Epoch 16/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8741 - loss: 0.4518
# Epoch 17/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8736 - loss: 0.4586
# Epoch 18/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8748 - loss: 0.4488
# Epoch 19/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8750 - loss: 0.4555
# Epoch 20/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8704 - loss: 0.4617
# Epoch 21/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8730 - loss: 0.4542
# Epoch 22/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8714 - loss: 0.4523
# Epoch 23/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8773 - loss: 0.4402
# Epoch 24/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8761 - loss: 0.4547
# Epoch 25/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8805 - loss: 0.4361
# Epoch 26/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8755 - loss: 0.4435
# Epoch 27/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8744 - loss: 0.4510
# Epoch 28/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8765 - loss: 0.4450
# Epoch 29/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8777 - loss: 0.4463
# Epoch 30/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8739 - loss: 0.4547
# Epoch 31/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8745 - loss: 0.4462
# Epoch 32/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8759 - loss: 0.4405
# Epoch 33/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8814 - loss: 0.4336
# Epoch 34/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8807 - loss: 0.4224
# Epoch 35/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8774 - loss: 0.4386
# Epoch 36/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8771 - loss: 0.4405
# Epoch 37/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8826 - loss: 0.4208
# Epoch 38/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8821 - loss: 0.4223
# Epoch 39/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8774 - loss: 0.4388
# Epoch 40/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8812 - loss: 0.4286
# Epoch 41/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8773 - loss: 0.4300
# Epoch 42/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8791 - loss: 0.4295
# Epoch 43/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8767 - loss: 0.4370
# Epoch 44/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8804 - loss: 0.4200
# Epoch 45/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8824 - loss: 0.4187
# Epoch 46/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8811 - loss: 0.4262
# Epoch 47/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8775 - loss: 0.4262
# Epoch 48/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8827 - loss: 0.4169
# Epoch 49/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8842 - loss: 0.4140
# Epoch 50/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8807 - loss: 0.4289
# Epoch 51/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8800 - loss: 0.4254
# Epoch 52/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8762 - loss: 0.4395
# Epoch 53/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8809 - loss: 0.4232
# Epoch 54/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8795 - loss: 0.4240
# Epoch 55/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8838 - loss: 0.4030
# Epoch 56/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8841 - loss: 0.3992
# Epoch 57/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8858 - loss: 0.4094
# Epoch 58/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8846 - loss: 0.4055
# Epoch 59/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8805 - loss: 0.4153
# Epoch 60/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8822 - loss: 0.4134
# Epoch 61/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8847 - loss: 0.4151
# Epoch 62/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8842 - loss: 0.4161
# Epoch 63/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8793 - loss: 0.4206
# Epoch 64/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8830 - loss: 0.4050
# Epoch 65/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8810 - loss: 0.4084
# Epoch 66/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8847 - loss: 0.4033
# Epoch 67/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8820 - loss: 0.4077
# Epoch 68/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8861 - loss: 0.4034
# Epoch 69/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.8864 - loss: 0.3948
# Epoch 70/70
# 214/214 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.8835 - loss: 0.4045

# %% [markdown]
# ### Test the model

# %%
def word_generator(input_text_arrays, num_pred_words):
    for i in range(num_pred_words):
        tokenized_my_samples = tkn.texts_to_sequences(input_text_arrays)
        tokenized_my_samples = pad_sequences(tokenized_my_samples, padding = 'pre', maxlen= max_length)

        prediction = model2.predict(tokenized_my_samples)
        prediction = np.argmax(prediction, axis=1)[0]

        for k in tkn.word_index.keys():
            if tkn.word_index[k] == prediction:
                input_text_arrays[0] = input_text_arrays[0] + ' ' + k
    
    return input_text_arrays
    

my_sample = ["I like the"]
word_generator(my_sample, 5)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# ['I like the people give up enemies sir']
